# %% [markdown]
# <a href="https://colab.research.google.com/github/utsavranjit/INFO-5717/blob/main/Lesson%201/Lesson_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This file introduce some examples for python beginners

# %%
# This program prints Hello, world!
print('Hello, world!')
# Out:
# Hello, world!

# %%
# This program adds two numbers
num1 = 1.5
num2 = 6.3
# Add two numbers
sum = float(num1) + float(num2)
# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# The sum of 1.5 and 6.3 is 7.8

# %%
# Store input numbers
num1 = input('Enter first number: ')
num2 = input('Enter second number: ')
# Add two numbers
sum = float(num1) + float(num2)
# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# Enter first number: 8.5
# Enter second number: 12.2
# The sum of 8.5 and 12.2 is 20.7

# %%
# Python Program to calculate the square root

# Note: change this value for a different result
num = 8 

# uncomment to take the input from the user
#num = float(input('Enter a number: '))
num_sqrt = num ** 0.5
print('The square root of %0.3f is %0.3f'%(num ,num_sqrt))
# Out:
# The square root of 8.000 is 2.828

# %%
# Python Program to find the area of triangle

a = 5
b = 6
c = 7

# Uncomment below to take inputs from the user
# a = float(input('Enter first side: '))
# b = float(input('Enter second side: '))
# c = float(input('Enter third side: '))

# calculate the semi-perimeter
s = (a + b + c) / 2

# calculate the area
area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
print('The area of the triangle is %0.2f' %area)
# Out:
# The area of the triangle is 14.70

# %%
# Program to generate a random number between 0 and 9

# import the random module
import random

print(random.randint(0,9))
# Out:
# 2

# %%
# Python program to check if the input year is a leap year or not

year = 2000

# To get year (integer input) from the user
# year = int(input("Enter a year: "))

if (year % 4) == 0:
   if (year % 100) == 0:
       if (year % 400) == 0:
           print("{0} is a leap year".format(year))
       else:
           print("{0} is not a leap year".format(year))
   else:
       print("{0} is a leap year".format(year))
else:
   print("{0} is not a leap year".format(year))
# Out:
# 2000 is a leap year

# %%
# Write a Python program to count the occurrences of each word in a given sentence.


# Define a function to count words, the input variable is a sentence
def word_count(str):
    counts = dict()
    words = str.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts
  

# Use the function defined above
print( word_count('the quick brown fox jumps over the lazy dog.'))
# Out:
# {'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog.': 1}

# %%
import matplotlib.pyplot as plt
import matplotlib.tri as tri
import numpy as np

# First create the x and y coordinates of the points.
n_angles = 36
n_radii = 8
min_radius = 0.25
radii = np.linspace(min_radius, 0.95, n_radii)

angles = np.linspace(0, 2 * np.pi, n_angles, endpoint=False)
angles = np.repeat(angles[..., np.newaxis], n_radii, axis=1)
angles[:, 1::2] += np.pi / n_angles

x = (radii * np.cos(angles)).flatten()
y = (radii * np.sin(angles)).flatten()
z = (np.cos(radii) * np.cos(3 * angles)).flatten()

# Create the Triangulation; no triangles so Delaunay triangulation created.
triang = tri.Triangulation(x, y)

# Mask off unwanted triangles.
triang.set_mask(np.hypot(x[triang.triangles].mean(axis=1),
                         y[triang.triangles].mean(axis=1))
                < min_radius)

# visualize the data above
fig1, ax1 = plt.subplots()
ax1.set_aspect('equal')
tpc = ax1.tripcolor(triang, z, shading='flat')
fig1.colorbar(tpc)
ax1.set_title('tripcolor of Delaunay triangulation, flat shading')
# Out:
# Text(0.5, 1.0, 'tripcolor of Delaunay triangulation, flat shading')

# %%
import matplotlib.pyplot as plt
import matplotlib.tri as tri
import numpy as np


xy = np.asarray([
    [-0.101, 0.872], [-0.080, 0.883], [-0.069, 0.888], [-0.054, 0.890],
    [-0.045, 0.897], [-0.057, 0.895], [-0.073, 0.900], [-0.087, 0.898],
    [-0.090, 0.904], [-0.069, 0.907], [-0.069, 0.921], [-0.080, 0.919],
    [-0.073, 0.928], [-0.052, 0.930], [-0.048, 0.942], [-0.062, 0.949],
    [-0.054, 0.958], [-0.069, 0.954], [-0.087, 0.952], [-0.087, 0.959],
    [-0.080, 0.966], [-0.085, 0.973], [-0.087, 0.965], [-0.097, 0.965],
    [-0.097, 0.975], [-0.092, 0.984], [-0.101, 0.980], [-0.108, 0.980],
    [-0.104, 0.987], [-0.102, 0.993], [-0.115, 1.001], [-0.099, 0.996],
    [-0.101, 1.007], [-0.090, 1.010], [-0.087, 1.021], [-0.069, 1.021],
    [-0.052, 1.022], [-0.052, 1.017], [-0.069, 1.010], [-0.064, 1.005],
    [-0.048, 1.005], [-0.031, 1.005], [-0.031, 0.996], [-0.040, 0.987],
    [-0.045, 0.980], [-0.052, 0.975], [-0.040, 0.973], [-0.026, 0.968],
    [-0.020, 0.954], [-0.006, 0.947], [ 0.003, 0.935], [ 0.006, 0.926],
    [ 0.005, 0.921], [ 0.022, 0.923], [ 0.033, 0.912], [ 0.029, 0.905],
    [ 0.017, 0.900], [ 0.012, 0.895], [ 0.027, 0.893], [ 0.019, 0.886],
    [ 0.001, 0.883], [-0.012, 0.884], [-0.029, 0.883], [-0.038, 0.879],
    [-0.057, 0.881], [-0.062, 0.876], [-0.078, 0.876], [-0.087, 0.872],
    [-0.030, 0.907], [-0.007, 0.905], [-0.057, 0.916], [-0.025, 0.933],
    [-0.077, 0.990], [-0.059, 0.993]])
x, y = np.rad2deg(xy).T

triangles = np.asarray([
    [67, 66,  1], [65,  2, 66], [ 1, 66,  2], [64,  2, 65], [63,  3, 64],
    [60, 59, 57], [ 2, 64,  3], [ 3, 63,  4], [ 0, 67,  1], [62,  4, 63],
    [57, 59, 56], [59, 58, 56], [61, 60, 69], [57, 69, 60], [ 4, 62, 68],
    [ 6,  5,  9], [61, 68, 62], [69, 68, 61], [ 9,  5, 70], [ 6,  8,  7],
    [ 4, 70,  5], [ 8,  6,  9], [56, 69, 57], [69, 56, 52], [70, 10,  9],
    [54, 53, 55], [56, 55, 53], [68, 70,  4], [52, 56, 53], [11, 10, 12],
    [69, 71, 68], [68, 13, 70], [10, 70, 13], [51, 50, 52], [13, 68, 71],
    [52, 71, 69], [12, 10, 13], [71, 52, 50], [71, 14, 13], [50, 49, 71],
    [49, 48, 71], [14, 16, 15], [14, 71, 48], [17, 19, 18], [17, 20, 19],
    [48, 16, 14], [48, 47, 16], [47, 46, 16], [16, 46, 45], [23, 22, 24],
    [21, 24, 22], [17, 16, 45], [20, 17, 45], [21, 25, 24], [27, 26, 28],
    [20, 72, 21], [25, 21, 72], [45, 72, 20], [25, 28, 26], [44, 73, 45],
    [72, 45, 73], [28, 25, 29], [29, 25, 31], [43, 73, 44], [73, 43, 40],
    [72, 73, 39], [72, 31, 25], [42, 40, 43], [31, 30, 29], [39, 73, 40],
    [42, 41, 40], [72, 33, 31], [32, 31, 33], [39, 38, 72], [33, 72, 38],
    [33, 38, 34], [37, 35, 38], [34, 38, 35], [35, 37, 36]])

xmid = x[triangles].mean(axis=1)
ymid = y[triangles].mean(axis=1)
x0 = -5
y0 = 52
zfaces = np.exp(-0.01 * ((xmid - x0) * (xmid - x0) +
                         (ymid - y0) * (ymid - y0)))

fig3, ax3 = plt.subplots()
ax3.set_aspect('equal')
tpc = ax3.tripcolor(x, y, triangles, facecolors=zfaces, edgecolors='k')
fig3.colorbar(tpc)
ax3.set_title('tripcolor of user-specified triangulation')
ax3.set_xlabel('Longitude (degrees)')
ax3.set_ylabel('Latitude (degrees)')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import collections, colors, transforms
import numpy as np

nverts = 50
npts = 100

# Make some spirals
r = np.arange(nverts)
theta = np.linspace(0, 2*np.pi, nverts)
xx = r * np.sin(theta)
yy = r * np.cos(theta)
spiral = np.column_stack([xx, yy])

# Fixing random state for reproducibility
rs = np.random.RandomState(19680801)

# Make some offsets
xyo = rs.randn(npts, 2)

# Make a list of colors cycling through the default series.
colors = [colors.to_rgba(c)
          for c in plt.rcParams['axes.prop_cycle'].by_key()['color']]

fig, axes = plt.subplots(2, 2)
fig.subplots_adjust(top=0.92, left=0.07, right=0.97,
                    hspace=0.3, wspace=0.3)
((ax1, ax2), (ax3, ax4)) = axes  # unpack the axes


col = collections.LineCollection([spiral], offsets=xyo,
                                 transOffset=ax1.transData)
trans = fig.dpi_scale_trans + transforms.Affine2D().scale(1.0/72.0)
col.set_transform(trans)  # the points to pixels transform
# Note: the first argument to the collection initializer
# must be a list of sequences of x,y tuples; we have only
# one sequence, but we still have to put it in a list.
ax1.add_collection(col, autolim=True)
# autolim=True enables autoscaling.  For collections with
# offsets like this, it is neither efficient nor accurate,
# but it is good enough to generate a plot that you can use
# as a starting point.  If you know beforehand the range of
# x and y that you want to show, it is better to set them
# explicitly, leave out the autolim kwarg (or set it to False),
# and omit the 'ax1.autoscale_view()' call below.

# Make a transform for the line segments such that their size is
# given in points:
col.set_color(colors)

ax1.autoscale_view()  # See comment above, after ax1.add_collection.
ax1.set_title('LineCollection using offsets')


# The same data as above, but fill the curves.
col = collections.PolyCollection([spiral], offsets=xyo,
                                 transOffset=ax2.transData)
trans = transforms.Affine2D().scale(fig.dpi/72.0)
col.set_transform(trans)  # the points to pixels transform
ax2.add_collection(col, autolim=True)
col.set_color(colors)


ax2.autoscale_view()
ax2.set_title('PolyCollection using offsets')

# 7-sided regular polygons

col = collections.RegularPolyCollection(
    7, sizes=np.abs(xx) * 10.0, offsets=xyo, transOffset=ax3.transData)
trans = transforms.Affine2D().scale(fig.dpi / 72.0)
col.set_transform(trans)  # the points to pixels transform
ax3.add_collection(col, autolim=True)
col.set_color(colors)
ax3.autoscale_view()
ax3.set_title('RegularPolyCollection using offsets')


# Simulate a series of ocean current profiles, successively
# offset by 0.1 m/s so that they form what is sometimes called
# a "waterfall" plot or a "stagger" plot.

nverts = 60
ncurves = 20
offs = (0.1, 0.0)

yy = np.linspace(0, 2*np.pi, nverts)
ym = np.max(yy)
xx = (0.2 + (ym - yy) / ym) ** 2 * np.cos(yy - 0.4) * 0.5
segs = []
for i in range(ncurves):
    xxx = xx + 0.02*rs.randn(nverts)
    curve = np.column_stack([xxx, yy * 100])
    segs.append(curve)

col = collections.LineCollection(segs, offsets=offs)
ax4.add_collection(col, autolim=True)
col.set_color(colors)
ax4.autoscale_view()
ax4.set_title('Successive data offsets')
ax4.set_xlabel('Zonal velocity component (m/s)')
ax4.set_ylabel('Depth (m)')
# Reverse the y-axis so depth increases downward
ax4.set_ylim(ax4.get_ylim()[::-1])


plt.show()

# %%
# Collecting data from tweeter

import tweepy
import csv


####input your credentials here
consumer_key = 'u7L1lnR7HN85dn1qnTFO1cegb'
consumer_secret = 'QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT'
access_token = '1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO'
access_token_secret = 'gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

#####United Airlines
# Open/Create a file to append data
csvFile = open('ua.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q="#UNT",count=100,lang="en", since="2019-07-03").items():
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# 2019-07-03 15:45:58 RT @sailoreze: The perfect troll Lol Saw this meme ad on campus #Memes #UNT #troll #shopping #Ads #hilarious https://t.co/uVFFozNQot
# 2019-07-03 15:36:02 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 15:31:27 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 15:28:24 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 14:42:28 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 14:40:38 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 14:38:04 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 14:32:25 RT @caseylopez13: Mason Fine at the top. #UNT #MeanGreen
# https://t.co/NKkKDxNZKD
# 2019-07-03 14:31:36 Worked full time. Went to school full time. Lived at home. Save 80% of my income. Earned my associates degree (2002… https://t.co/MGN9OAZoEh
# 2019-07-03 14:00:32 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 13:59:07 @brit2478 #UNT buses, operated by @RideDCTA will run their regular summer routes July 5 - is there a specific bus r… https://t.co/LHwqmt5HYM
# 2019-07-03 13:52:22 Mason Fine at the top. #UNT #MeanGreen
# https://t.co/NKkKDxNZKD
# 2019-07-03 13:39:46 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 13:17:18 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 13:01:15 ALUMNI NEWS: Ryan Taycher (BM '10, MA '13) and PhD candidate at Indiana has been appointed Lecturer of Music Theory… https://t.co/CZqqSLBw1q
# 2019-07-03 12:54:33 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 12:40:04 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 12:28:17 RT @read_nature: #Week of #July4th #celebrations 🥳 at the #home of the #brave (🇺🇸) - ÁGORA is an #eagle 🦅 (#UNT) #Nicolaita (#UMSNH) y #Lin…
# 2019-07-03 12:27:18 RT @readscience: #Week of #July4th #celebrations 🥳 at the #home of the #brave (🇺🇸) - ÁGORA is an #eagle 🦅 (#UNT) #Nicolaita (#UMSNH) y #Lin…
# 2019-07-03 12:20:08 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 12:16:51 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 11:09:15 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 10:08:45 RT @telallstare2000: @simonmaginn @Exfostercarer Jeremy #unt is an anti semite, to use the holocaust in that way is disgusting and by the w…
# 2019-07-03 10:02:52 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 09:18:03 RT @babybropatto: #unt invites the ERG, DUP, and local Tories, to Brexit negotiations.
# Those  that Scots gave an electoral mandate are ign…
# 2019-07-03 08:45:02 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 08:24:32 RT @UNTChoreoblock: What it do babbbyyy. 🔥🔥🔥🔥WORKSHOP ALERT. Check out our insta to find out how you can get $5 off this workshop for all 3…
# 2019-07-03 08:04:00 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 07:30:52 What jeremy #unt has said is 100% worse than anything chris williamson has said, where is the total condemnation by… https://t.co/XotEf4MIBH
# 2019-07-03 07:09:38 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 07:01:35 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 06:58:36 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 06:44:56 RT @UNTChoreoblock: What it do babbbyyy. 🔥🔥🔥🔥WORKSHOP ALERT. Check out our insta to find out how you can get $5 off this workshop for all 3…
# 2019-07-03 06:00:48 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 06:00:26 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 05:30:30 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 05:29:29 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 05:27:43 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 05:19:59 @simonmaginn @Exfostercarer Jeremy #unt is an anti semite, to use the holocaust in that way is disgusting and by th… https://t.co/FKjLxPSTH1
# 2019-07-03 05:12:31 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 04:57:04 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 04:49:26 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 04:39:31 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 04:32:49 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 04:29:32 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 04:25:47 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 04:23:42 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 04:06:56 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 04:02:31 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:59:16 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:57:33 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:55:56 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:54:49 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:38:18 RT @UNTChoreoblock: What it do babbbyyy. 🔥🔥🔥🔥WORKSHOP ALERT. Check out our insta to find out how you can get $5 off this workshop for all 3…
# 2019-07-03 03:29:31 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:26:20 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:26:12 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:23:34 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:21:11 RT @UNTChoreoblock: What it do babbbyyy. 🔥🔥🔥🔥WORKSHOP ALERT. Check out our insta to find out how you can get $5 off this workshop for all 3…
# 2019-07-03 03:20:55 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:20:51 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:20:14 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:19:43 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:19:33 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:17:30 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 03:17:19 What it do babbbyyy. 🔥🔥🔥🔥WORKSHOP ALERT. Check out our insta to find out how you can get $5 off this workshop for a… https://t.co/9UAknAdiTz
# 2019-07-03 03:16:38 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 02:57:32 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 02:50:53 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 02:50:53 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 02:43:43 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 02:27:00 The perfect troll Lol Saw this meme ad on campus #Memes #UNT #troll #shopping #Ads #hilarious https://t.co/uVFFozNQot
# 2019-07-03 02:26:55 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 02:25:52 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 02:21:23 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 02:18:15 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 02:13:30 @charliekirk11 I hope you’re coming to #UNT ! https://t.co/EIKMNjOPbc
# 2019-07-03 01:52:19 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:50:55 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:48:02 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:31:21 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:27:56 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:26:23 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:25:52 RT @NT_CoachJ: Welcome to #UNT @summmmer_x3! 💚 https://t.co/OTztuC27Y3
# 2019-07-03 01:18:39 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:17:36 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:12:35 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:11:46 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:09:47 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:09:35 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:09:07 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:01:14 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 01:00:59 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:57:44 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:57:37 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:54:35 Welcome to #UNT @summmmer_x3! 💚 https://t.co/OTztuC27Y3
# 2019-07-03 00:51:37 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:50:25 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:50:12 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:48:50 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:47:02 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:46:22 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:44:27 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:43:50 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:38:54 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:38:23 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:37:52 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:36:21 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:35:22 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:31:59 @neauxna A fresh graduate from #UNT preparing to move on my own to a new state to be an #AmeriCorpsVISTA
# 2019-07-03 00:27:50 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:27:43 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:25:00 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:22:04 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:20:12 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:18:52 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:13:32 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:12:19 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:11:26 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:11:13 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:06:39 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:03:22 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…
# 2019-07-03 00:02:31 RT @MeanGreenReady: ATTN: MISSING CHILD
#
# Sarbresh was reported missing off of W. Prairie St. - just off the #UNT campus near Traditions and…

# %%
pip install textblob

### Tools for NLP: https://textblob.readthedocs.io/en/dev/quickstart.html#
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.6/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.6/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk>=3.1->textblob) (1.12.0)

# %%
from textblob import TextBlob

# Translation and Language Detection
chinese_blob = TextBlob(u"美丽优于丑陋")
result = chinese_blob.translate(from_lang="zh-CN", to='en')
print("Translation result: " + str(result))

b = TextBlob(u"بسيط هو أفضل من مجمع")
b.detect_language()
# Out:
# Translation result: Beauty is better than ugly
# 'ar'
